# %%
# !pip install imbalanced-learn

# %%
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split, StratifiedKFold, cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.metrics import accuracy_score

from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier

from imblearn.over_sampling import SMOTE

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("/content/Creditcard_data.csv")
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0     0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1     0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2     1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3     1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4     2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
X = df.drop('Class', axis=1)
y = df['Class']

scaler = StandardScaler()
X = scaler.fit_transform(X)

# %%
samplings = {}

# Sampling1 — Random Sampling
X_train1, X_test1, y_train1, y_test1 = train_test_split(
    X, y, test_size=0.25, random_state=42)
samplings["Sampling1"] = (X_train1, X_test1, y_train1, y_test1)


# Sampling2 — Correct Cluster Sampling (FIXED)

kmeans = KMeans(n_clusters=5, random_state=42)
clusters = kmeans.fit_predict(X)

df_cluster = pd.DataFrame(X)
df_cluster['Class'] = y.values
df_cluster['Cluster'] = clusters

# Select multiple clusters to ensure both classes exist
selected_clusters = df_cluster['Cluster'].unique()[:3]

cluster_sample = df_cluster[df_cluster['Cluster'].isin(selected_clusters)]

X_train2 = cluster_sample.drop(['Class','Cluster'], axis=1)
y_train2 = cluster_sample['Class']

samplings["Sampling2"] = (X_train2, X_test1, y_train2, y_test1)



# Sampling3 — Stratified Sampling
X_train3, X_test3, y_train3, y_test3 = train_test_split(
    X, y, test_size=0.25, stratify=y, random_state=42)
samplings["Sampling3"] = (X_train3, X_test3, y_train3, y_test3)


# Sampling4 — Bootstrap Sampling
n = len(X)
idx = np.random.choice(np.arange(n), size=n, replace=True)
X_boot = X[idx]
y_boot = y.iloc[idx]

X_train4, X_test4, y_train4, y_test4 = train_test_split(
    X_boot, y_boot, test_size=0.25, random_state=42)
samplings["Sampling4"] = (X_train4, X_test4, y_train4, y_test4)


# Sampling5 — SMOTE Balanced Sampling
smote = SMOTE(random_state=42)
X_sm, y_sm = smote.fit_resample(X, y)

X_train5, X_test5, y_train5, y_test5 = train_test_split(
    X_sm, y_sm, test_size=0.25, random_state=42)

samplings["Sampling5"] = (X_train5, X_test5, y_train5, y_test5)

# %%
models = {
    "M1": LogisticRegression(),
    "M2": DecisionTreeClassifier(),
    "M3": RandomForestClassifier(n_estimators=200),
    "M4": SVC(),
    "M5": KNeighborsClassifier()
}

# %%
final_table = pd.DataFrame(index=models.keys(), columns=samplings.keys())

for samp_name, (X_tr, X_te, y_tr, y_te) in samplings.items():
    for model_name, model in models.items():
        model.fit(X_tr, y_tr)
        preds = model.predict(X_te)
        acc = accuracy_score(y_te, preds) * 100
        final_table.loc[model_name, samp_name] = round(acc, 2)

final_table
# Out:
#    Sampling1 Sampling2 Sampling3 Sampling4 Sampling5
# M1     98.96     96.89     98.96     100.0     92.93
# M2     97.93     100.0     97.41     100.0     97.38
# M3     98.96     100.0     98.96     100.0     99.21
# M4     98.96     98.96     98.96     100.0      96.6
# M5     98.96     98.96     98.96     99.48     93.98

# %%
# Convert values to float
final_table = final_table.astype(float)

# Find maximum accuracy value
max_value = final_table.max().max()

# Find location (model & sampling)
best_model = final_table.stack().idxmax()[0]
best_sampling = final_table.stack().idxmax()[1]

print("======================================")
print(" BEST SAMPLING TECHNIQUE & MODEL ")
print("======================================")
print(f"Highest Accuracy = {max_value:.2f}%")
print(f"Best Sampling Technique = {best_sampling}")
print(f"Best Performing Model = {best_model}")
# Out:
# ...
#  BEST SAMPLING TECHNIQUE & MODEL
# ...
# Highest Accuracy = 100.00%
# Best Sampling Technique = Sampling4
# Best Performing Model = M1
